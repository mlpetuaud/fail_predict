# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="white")

## Setting max displayed rows to 500, in order to display the full output of any command
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
df_total = pd.read_csv("./Data/StockEtablissementHistorique_utf8.csv")
# Out:
# /Users/marie/.pyenv/versions/3.9.5/envs/simplon/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (8,9,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_total.head()
# Out:
#     siren  nic        siret     dateFin   dateDebut etatAdministratifEtablissement  changementEtatAdministratifEtablissement   enseigne1Etablissement enseigne2Etablissement enseigne3Etablissement  changementEnseigneEtablissement denominationUsuelleEtablissement  changementDenominationUsuelleEtablissement activitePrincipaleEtablissement nomenclatureActivitePrincipaleEtablissement  changementActivitePrincipaleEtablissement caractereEmployeurEtablissement  changementCaractereEmployeurEtablissement
# ...

# %%
df_activity = df_total[df_total["dateFin"].isna()]

# %%
df_activity_siren = df_activity["siren"]

# %%
df_activity_siren = df_activity_siren.drop_duplicates()

# %%
df_sample_1 = df_activity_siren.sample(n=150000, replace=True)

# %%
df_sample_1 = df_sample_1.reset_index(drop=True)

# %%
df_sample_11 = df_sample_1.drop([i for i in range (50000, df_sample_1.shape[0])])

# %%
df_sample_11.to_csv("./Data/test.csv", index=False)

# %%
df_sample_12 = df_sample_1.drop([i for i in range (100000, df_sample_1.shape[0])])

# %%
df_sample_12 = df_sample_12.drop([i for i in range (0,50000)])

# %%
df_sample_12.to_csv("./Data/sample_12.csv", index=False)

# %%
df_sample_11.to_excel("./Data/Sample_11.xlsx", index=False)

# %%
df_sample_13 = df_sample_1.drop([i for i in range (0,100000)])

# %%
df_sample_13.to_csv("./Data/Entreprises saines/siren_3.csv", index=False)

# %%
df_sample_2 = df_activity_siren.sample(n=200000, replace=True)

# %%
df_sample_2 = df_sample_2.reset_index(drop=True)

# %%
df_sample_3 = df_activity_siren.sample(n=300000, replace=True)

# %%
df_sample_3.to_csv("./Data/Entreprises saines/reserve_300K_siren_supplementaires.csv", index=False)

# %%
df_sample_21 = df_sample_2.drop([i for i in range (50000, df_sample_2.shape[0])])

# %%
df_sample_21.to_csv("./Data/Entreprises saines/siren_4.csv", index=False)

# %%
df_sample_22 = df_sample_2.drop([i for i in range (100000, df_sample_2.shape[0])])

# %%
df_sample_22 = df_sample_22.drop([i for i in range (0, 50000)])

# %%
df_sample_22.to_csv("./Data/Entreprises saines/siren_5.csv", index=False)

# %%
df_sample_23 = df_sample_2.drop([i for i in range (150000, df_sample_2.shape[0])])

# %%
df_sample_23 = df_sample_23.drop([i for i in range (0, 100000)])

# %%
df_sample_23.to_csv("./Data/Entreprises saines/siren_6.csv", index=False)

# %%
df_sample_24 = df_sample_2.drop([i for i in range (0, 150000)])

# %%
(df_sample_24.values == df_sample_23.values).sum()
# Out:
# 0

# %%
df_sample_24.to_csv("./Data/Entreprises saines/siren_7.csv", index=False)

# %%
def get_chunk():
    for start in [50000, 100000]:
    df_sample_i = df_sample_1.drop([i for i in range (start, df_sample_1.shape[0])])
    return df_sample_i

# %%
df_sample_11 = df_sample_1.drop([i for i in range (50000, df_sample_1.shape[0])])

# %%
df_sample_11 = df_sample_11["siren"]

# %%
df_sample_11.to_excel("./Data/Sample_11.xlsx", index=False)

# %%
df_sample_12 = get_

# %%
df_sample_1.to_excel("./Data/Sample_1.xlsx")

# %%
df_total["dateFin"] = pd.to_datetime(df_total["dateFin"], errors='coerce')

# %%
df_obj = df_total[df_total["dateFin"].dt.year > 2018]

# %%
df_activity = df_total[df_total["dateFin"].isna()]

# %%
df_activity.shape
# Out:
# (32084298, 18)

# %%
sample_1 = df_activity.sample(n=20000, replace=True)

# %%
siret_1 = sample_1["siret"]

# %%
siret_1.to_csv("./Data/siret_1.csv")

# %%
sample_1["siret"].value_counts()
# Out:
# 26840117100049    2
# 64204389700056    2
# 55208131731187    2
# 51374962200017    2
# 48827008300014    1
#                  ..
# 41266297500041    1
# 33258665000019    1
# 87280220200186    1
# 3911322000014     1
# 32567411700016    1
# Name: siret, Length: 19996, dtype: int64

# %%
df_obj.shape
# Out:
# (3221108, 18)

# %%
siret_1 = pd.read_csv("./Data/siret_1.csv")

# %%
siret_1.to_excel("./Data/siret_1.xlsx")

# %%
pip install openpyxl
# Out:
# ...
#      |████████████████████████████████| 242 kB 5.0 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/Users/marie/.pyenv/versions/3.9.5/envs/simplon/bin/python3.9 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
#df_ok = pd.concat([df_obj, df_activity])

# %%
df_obj.sample(n=20000, replace=True)

# %%
df_obj.isna().sum()
# Out:
# siren                                                0
# nic                                                  0
# siret                                                0
# dateFin                                              0
# dateDebut                                            0
# etatAdministratifEtablissement                    6465
# changementEtatAdministratifEtablissement             0
# enseigne1Etablissement                         2840301
# enseigne2Etablissement                         3218007
# enseigne3Etablissement                         3220316
# changementEnseigneEtablissement                      0
# denominationUsuelleEtablissement               2669801
# changementDenominationUsuelleEtablissement           0
# activitePrincipaleEtablissement                   8697
# nomenclatureActivitePrincipaleEtablissement       8697
# changementActivitePrincipaleEtablissement            0
# caractereEmployeurEtablissement                  10978
# ...

# %%
path = "./Data/Entreprises_défaillantes.csv"
data = pd.read_csv(path, delimiter=";")

# %%
data.columns.to_list()
# Out:
# ['SIREN',
#  'Dénomination',
#  'Code APE',
#  'Adresse',
#  'Code postal',
#  'Tranche effectifs',
#  'SIRET',
#  'Date de création',
#  'TOTAL (II) (net) (BJNET) 2018 (€)',
#  'TOTAL (II) (net) (BJNET) 2016 (€)',
#  'Clients et comptes rattachés (3) (net) (BXNET) 2018 (€)',
#  'Clients et comptes rattachés (3) (net) (BXNET) 2016 (€)',
#  'Autres créances (3) (net) (BZNET) 2018 (€)',
#  'Autres créances (3) (net) (BZNET) 2016 (€)',
#  'Valeurs mobilières de placement (net) (CDNET) 2018 (€)',
#  'Valeurs mobilières de placement (net) (CDNET) 2016 (€)',
#  'Disponibilités (net) (CFNET) 2018 (€)',
#  'Disponibilités (net) (CFNET) 2016 (€)',
#  'TOTAL (III) (net) (CJNET) 2018 (€)',
#  'TOTAL (III) (net) (CJNET) 2016 (€)',
#  'TOTAL GENERAL(I à VI) (net) (CONET) 2018 (€)',
#  'TOTAL GENERAL(I à VI) (net) (CONET) 2016 (€)',
#  'Capital social ou individuel (1) (DA) 2018 (€)',
#  'Capital social ou individuel (1) (DA) 2016 (€)',
#  'Report à nouveau (DH) 2018 (€)',
# ...

# %% [markdown]
# ## A rajouter comme infos :
# - entreprise active ?
# - type de procédure (PC, entreprises en difficulté)
# - date de la procédure collective

# %% [markdown]
# ## A faire :
# - Spliter les dataframes en données 2018 et 2016
# - Renommer les colonnes
# - Calculer les statistiques descriptives de chacune des colonnes.

# %%
data.isnull().sum()
# Out:
# SIREN                                                                                           0
# Dénomination                                                                                    0
# Code APE                                                                                        0
# Adresse                                                                                        16
# Code postal                                                                                     0
# Tranche effectifs                                                                             180
# SIRET                                                                                           0
# Date de création                                                                                0
# TOTAL (II) (net) (BJNET) 2018 (€)                                                               0
# TOTAL (II) (net) (BJNET) 2016 (€)                                                               0
# ...

# %%
# tout simplement ! pour afficher la totalité du dataset utiliser la heatmap de seaborn sur un booleen comme df.isna !
# autre possibilité : fonction img show de matplotlib

plt.figure(figsize=(20,10))
sns.heatmap(data.isna(), cbar=False)
# ici en blanc on voit les valeurs manquantes
# Out:
# <AxesSubplot:>
